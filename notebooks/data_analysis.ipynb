# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("../data/raw/dht11_new.csv")  # Replace "your_data.csv" with the actual file name

# Display the first few rows to get an overview of the dataset
print("First 5 rows of the dataset:")
data.head()
# Out:
# First 5 rows of the dataset:
#      id  temperature  humidity  mq2_analog  mq2_digital  sound_analog  \
# 0  2211         32.3      53.0       148.0          1.0         192.0
# 1  2212         32.3      53.0       148.0          1.0         184.0
# 2  2213         32.3      53.0       148.0          1.0         189.0
# 3  2214         32.3      53.0       147.0          1.0         189.0
# 4  2215         32.3      53.0       147.0          1.0         184.0
#
#    sound_digital  mq9_analog             datatime  mq9_digital  mq8_analog  \
# 0            0.0       141.0  2024-04-06 22:39:11          1.0       205.0
# 1            0.0       141.0  2024-04-06 22:39:18          1.0       205.0
# 2            0.0       141.0  2024-04-06 22:39:24          1.0       205.0
# 3            0.0       141.0  2024-04-06 22:39:31          1.0       205.0
# 4            0.0       141.0  2024-04-06 22:39:38          1.0       205.0
#
#    mq8_digital  pm25_density  pm10_density
# 0          1.0        242.28        186.67
# 1          1.0        233.98        189.99
# 2          1.0        246.43        212.40
# 3          1.0        234.81        183.35
# 4          1.0        237.30        221.53

# %%
data
# Out:
#           id  temperature  humidity  mq2_analog  mq2_digital  sound_analog  \
# 0       2211         32.3      53.0       148.0          1.0         192.0
# 1       2212         32.3      53.0       148.0          1.0         184.0
# 2       2213         32.3      53.0       148.0          1.0         189.0
# 3       2214         32.3      53.0       147.0          1.0         189.0
# 4       2215         32.3      53.0       147.0          1.0         184.0
# ...      ...          ...       ...         ...          ...           ...
# 61995  64206         33.3      36.0        47.0          1.0         138.0
# 61996  64207         33.3      36.0        47.0          1.0         134.0
# 61997  64208         33.3      36.0        47.0          1.0         138.0
# 61998  64209         33.3      36.0        47.0          1.0         140.0
# 61999  64210         33.3      36.0        47.0          1.0         134.0
#
#        sound_digital  mq9_analog             datatime  mq9_digital  \
# 0                0.0       141.0  2024-04-06 22:39:11          1.0
# 1                0.0       141.0  2024-04-06 22:39:18          1.0
# 2                0.0       141.0  2024-04-06 22:39:24          1.0
# 3                0.0       141.0  2024-04-06 22:39:31          1.0
# 4                0.0       141.0  2024-04-06 22:39:38          1.0
# ...              ...         ...                  ...          ...
# 61995            0.0       198.0  2024-11-23 13:45:10          1.0
# 61996            0.0       197.0  2024-11-23 13:45:16          1.0
# 61997            0.0       198.0  2024-11-23 13:45:23          1.0
# 61998            0.0       198.0  2024-11-23 13:45:30          1.0
# 61999            0.0       199.0  2024-11-23 13:45:36          1.0
#
#        mq8_analog  mq8_digital  pm25_density  pm10_density
# 0           205.0          1.0        242.28        186.67
# 1           205.0          1.0        233.98        189.99
# 2           205.0          1.0        246.43        212.40
# 3           205.0          1.0        234.81        183.35
# 4           205.0          1.0        237.30        221.53
# ...           ...          ...           ...           ...
# 61995       105.0          1.0        209.91        122.75
# 61996       104.0          1.0        219.04        126.90
# 61997       104.0          1.0        211.57        131.05
# 61998       104.0          1.0        205.76        117.77
# 61999       105.0          1.0        206.59        128.56
#
# [62000 rows x 14 columns]

# %%
# Check the shape of the dataset (number of rows and columns)
print("\nShape of the dataset (rows, columns):")
data.shape
# Out:
# Shape of the dataset (rows, columns):
# (62000, 14)

# %%
# Check column names and data types
print("\nColumn Names and Data Types:")
data.dtypes
# Out:
# Column Names and Data Types:
# id                 int64
# temperature      float64
# humidity         float64
# mq2_analog       float64
# mq2_digital      float64
# sound_analog     float64
# sound_digital    float64
# mq9_analog       float64
# datatime          object
# mq9_digital      float64
# mq8_analog       float64
# mq8_digital      float64
# pm25_density     float64
# pm10_density     float64
# dtype: object

# %%
# Check for missing values in each column
print("\nMissing Values in Each Column:")
data.isnull().sum()
# Out:
# Missing Values in Each Column:
# id               0
# temperature      0
# humidity         0
# mq2_analog       2
# mq2_digital      7
# sound_analog     3
# sound_digital    3
# mq9_analog       6
# datatime         0
# mq9_digital      4
# mq8_analog       2
# mq8_digital      4
# pm25_density     3
# pm10_density     3
# dtype: int64

# %%
# Display summary statistics for numerical columns
print("\nSummary Statistics for Numerical Columns:")
data.describe()
# Out:
# Summary Statistics for Numerical Columns:
#                  id   temperature      humidity    mq2_analog   mq2_digital  \
# count  62000.000000  62000.000000  62000.000000  61998.000000  61993.000000
# mean   33210.500000     30.424016     45.627548     50.659376      0.987047
# std    17898.002682      6.573178     14.442559     43.660575      0.113073
# min     2211.000000    -18.600000      0.000000      0.000000      0.000000
# 25%    17710.750000     29.300000     39.000000     33.000000      1.000000
# 50%    33210.500000     32.300000     45.000000     46.000000      1.000000
# 75%    48710.250000     33.300000     53.000000     53.000000      1.000000
# max    64210.000000     40.600000     83.000000   1019.000000      1.000000
#
#        sound_analog  sound_digital    mq9_analog   mq9_digital    mq8_analog  \
# count  61997.000000   61997.000000  61994.000000  61996.000000  61998.000000
# mean     135.467136       0.093456    193.257702      0.943706    116.404513
# std       35.321906       0.291073     43.552613      0.230490     53.530826
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%      130.000000       0.000000    163.000000      1.000000     92.000000
# 50%      138.000000       0.000000    191.000000      1.000000    102.000000
# 75%      145.000000       0.000000    228.000000      1.000000    127.000000
# max      785.000000       1.000000    638.000000      1.000000   1023.000000
#
#         mq8_digital  pm25_density  pm10_density
# count  61996.000000  61997.000000  61997.000000
# mean       0.978983    231.158352    185.724883
# std        0.143444     37.747131     36.266836
# min        0.000000     -0.100000     -0.100000
# 25%        1.000000    212.400000    165.090000
# 50%        1.000000    227.340000    182.520000
# 75%        1.000000    245.600000    201.610000
# max        1.000000    849.070000    808.400000

# %%
# Check for unique values in each column to understand categorical features
print("\nUnique Values in Each Column:")
{column: data[column].nunique() for column in data.columns}
# Out:
# Unique Values in Each Column:
# {'id': 62000,
#  'temperature': 116,
#  'humidity': 58,
#  'mq2_analog': 413,
#  'mq2_digital': 2,
#  'sound_analog': 385,
#  'sound_digital': 2,
#  'mq9_analog': 393,
#  'datatime': 60919,
#  'mq9_digital': 2,
#  'mq8_analog': 513,
#  'mq8_digital': 2,
#  'pm25_density': 537,
#  'pm10_density': 542}

# %%
import matplotlib.pyplot as plt

# Ensure 'datatime' column is in datetime format
data['datatime'] = pd.to_datetime(data['datatime'])

# Extract the hour from 'datatime' for grouping
data['hour'] = data['datatime'].dt.hour

# Group by 'hour' and calculate the mean for each parameter
hourly_avg = data.groupby('hour').mean()

# Plot each parameter separately by hour and save each plot
for column in hourly_avg.columns:
    if column != 'id':  # Exclude 'id' if it's not a relevant parameter
        plt.figure(figsize=(10, 6))
        plt.plot(hourly_avg.index, hourly_avg[column], marker='o', linestyle='-')
        plt.title(f"Average {column} by Hour of the Day")
        plt.xlabel("Hour of Day")
        plt.ylabel(f"Average {column}")
        plt.grid(True)
        plt.xticks(range(0, 24))  # X-axis ticks for each hour
        
        # Save the plot as a PNG file with the parameter name in the filename
        filename = f"average_{column}_by_hour.png"
        plt.savefig(filename, format='png')
        
        # Display the plot
        plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Convert 'datatime' column to datetime format if not already done
data['datatime'] = pd.to_datetime(data['datatime'])

# Extract the date (year-month-day) from 'datatime' for grouping
data['day'] = data['datatime'].dt.date

# Group by 'day' and calculate the mean for each parameter
daily_avg = data.groupby('day').mean()

# Create 'graph' folder if it doesn't exist
output_dir = "graph"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Plot each parameter separately by day and save each plot
for column in daily_avg.columns:
    if column != 'id':  # Exclude 'id' if it's not a relevant parameter
        plt.figure(figsize=(12, 6))
        plt.plot(daily_avg.index, daily_avg[column], marker='o', linestyle='-')
        plt.title(f"Average {column} by Day")
        plt.xlabel("Day")
        plt.ylabel(f"Average {column}")
        plt.grid(True)
        plt.xticks(rotation=45)  # Rotate day labels for readability
        
        # Save the plot as a PNG file in the 'graph' folder with the parameter name in the filename
        filename = os.path.join(output_dir, f"average_{column}_by_day.png")
        plt.savefig(filename, format='png')
        
        # Display the plot
        # plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# Ensure 'datatime' column is in datetime format
data['datatime'] = pd.to_datetime(data['datatime'])

# Extract the hour from 'datatime' for grouping
data['hour'] = data['datatime'].dt.hour

# Group by 'hour' and calculate the mean for each parameter
hourly_avg = data.groupby('hour').mean().reset_index()

# List of parameters to plot (exclude 'id', 'datatime', and 'digital' columns)
parameters = [col for col in hourly_avg.columns if 'digital' not in col and col != 'id' and col != 'datatime']

# Generate and show a plot for each parameter
for column in parameters:
    # Create a figure for each parameter
    fig = go.Figure()

    fig.add_trace(
        go.Scatter(
            x=hourly_avg['hour'],
            y=hourly_avg[column],
            mode='lines+markers',
            name=column,
            line=dict(width=2),
            marker=dict(size=6)
        )
    )

    # Update layout for better presentation
    fig.update_layout(
        title=f"Average {column} by Hour of the Day",
        xaxis_title="Hour of Day",
        yaxis_title=f"Average {column}",
        hovermode="closest",
        template="plotly_dark",  # Use a dark theme for a beautiful look
        xaxis=dict(tickmode="linear", tick0=0, dtick=1),  # Set tick marks for each hour
        width=1000,
        height=600
    )

    # Show the interactive plot
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'datetime.date' and 'datetime.date'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       8 data['hour'] = data['datatime'].dt.hour
#      10 # Group by 'hour' and calculate the mean for each parameter
# ---> 11 hourly_avg = data.groupby('hour').mean().reset_index()
#      13 # List of parameters to plot (exclude 'id', 'datatime', and 'digital' columns)
#      14 parameters = [col for col in hourly_avg.columns if 'digital' not in col and col != 'id' and col != 'datatime']
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]
